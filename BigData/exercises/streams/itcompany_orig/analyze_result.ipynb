# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./res.csv')
df.head()
# Out:
#      values
# 0  1.000000
# 1  0.986921
# 2  0.981030
# 3  0.952280
# 4  0.945799

# %%
plt.plot(df)

# %%
df2 = pd.read_csv('./res2.csv')
df2.head()
# Out:
#     skill  salary
# 0     C#     1185
# 1  Storm      881
# 2  C/C++     1159
# 3   Java     1148
# 4   Hive      891

# %%
df2['salary'][0]
# Out:
# 1185

# %%
from matplotlib.pyplot import figure

figure(figsize=(10, 8), dpi=80)

plt.bar(df2['skill'],df2['salary'],align='center')
plt.xlabel('skill')
plt.ylabel('avg salary')
# Out:
# Text(0, 0.5, 'avg salary')
